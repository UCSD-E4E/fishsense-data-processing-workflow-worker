# %%
from fishsense_api_sdk.client import Client
from tqdm.asyncio import tqdm_asyncio
from fishsense_api_sdk.models.species_label import SpeciesLabel
from fishsense_api_sdk.models.dive_frame_cluster import DiveFrameCluster
from datetime import datetime, timezone
from tqdm.notebook import tqdm
from fishsense_data_processing_workflow_worker.config import settings
from fishsense_api_sdk.models.data_source import DataSource

# %%
async with Client(settings.fishsense_api.url, settings.fishsense_api.username, settings.fishsense_api.password) as client:
    dives = await client.dives.get()
    dives = [dive for dive in dives if dive.priority == "HIGH"]

len(dives), dives[0]
# Out:
# (8,
#  Dive(id=383, name='062624_FiveSeas_FSL03', path='2025-02-10 REEF Data Dump SMILE 6/CubaTrip2024_FSL03/062624_FiveSeas_FSL03', dive_datetime=datetime.datetime(2024, 6, 26, 7, 52, 45, tzinfo=TzInfo(0)), priority=<Priority.HIGH: 'HIGH'>, flip_dive_slate=None, camera_id=3, dive_slate_id=None))

# %%
async with Client(settings.fishsense_api.url, settings.fishsense_api.username, settings.fishsense_api.password) as client:
    dive_image_groups_list = await tqdm_asyncio.gather(*[client.images.get_clusters(dive.id, DataSource.PREDICTION.value) for dive in dives])

len(dive_image_groups_list), len(dive_image_groups_list[0]), dive_image_groups_list[0][0]
# Out:
# 100%|██████████| 8/8 [00:03<00:00,  2.51it/s]
# (8,
#  13,
#  DiveFrameCluster(id=3044, image_ids=[111930, 111930, 111930, 111930, 111930, 111930, 111930, 111930, 111930, 111930, 111930, 111930, 111930, 111931, 111931, 111931, 111931, 111931, 111931, 111931, 111931, 111931, 111931, 111931, 111931, 111931, 111932, 111932, 111932, 111932, 111932, 111932, 111932, 111932, 111932, 111932, 111932, 111932, 111932, 111933, 111933, 111933, 111933, 111933, 111933, 111933, 111933, 111933, 111933, 111933, 111933, 111933, 111934, 111934, 111934, 111934, 111934, 111934, 111934, 111934, 111934, 111934, 111934, 111934, 111934], data_source=<DataSource.PREDICTION: 'PREDICTION'>, updated_at=datetime.datetime(2025, 12, 8, 20, 59, 30, 781, tzinfo=TzInfo(0)), dive_id=383, fish_id=None))

# %%
async with Client(settings.fishsense_api.url, settings.fishsense_api.username, settings.fishsense_api.password) as client:
    species_labels = await tqdm_asyncio.gather(*[client.labels.get_species_labels(dive.id) for dive in dives])
    species_labels = [label for sublist in species_labels for label in sublist]

len(species_labels), species_labels[0]
# Out:
# 100%|██████████| 8/8 [00:01<00:00,  5.00it/s]
# (1218,
#  SpeciesLabel(id=1179, label_studio_task_id=224623, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/708d385dc06f8fd60c46683478e77b2b', updated_at=datetime.datetime(2025, 12, 9, 1, 2, 5, 406207, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=2043.1891467172798, laser_y=1355.6551899834365, laser_label='Red Laser', content_of_image='Slate, Laser on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134871, 'result': [{'id': 'X-QEwfPU-K', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'w_p1HuzBVT', 'type': 'keypointlabels', 'value': {'x': 50.901573161865464, 'y': 44.94877950873463, 'width': 0.2762390456930156, 'keypointlabels': ['Red Laser']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'created_username': ' alli@reef.org, 10', 'created_ago': '2\xa0hours, 4\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T00:59:46.458952Z', 'updated_at': '2025-12-09T01:02:05.406207Z', 'draft_created_at': '2025-12-09T00:59:39.983774Z', 'lead_time': 31.552999999999997, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224623, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134871', 'annotations_results': '[{id:X-QEwfPU-K, type:taxonomy, value:{taxonomy:[[Slate, Laser on slate]]}, origin:manual, to_name:image, from_name:species},{id:w_p1HuzBVT, type:keypointlabels, value:{x:50.9, y:44.95, width:0.28, keypointlabels:[Red Laser]}, origin:manual, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'annotators': [10], 'avg_lead_time': 31.552999999999997, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T00:59:46.458952Z', 'created_at': '2025-12-08T22:46:39.907777Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/708d385dc06f8fd60c46683478e77b2b'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224623, 'inner_id': 1, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:02:05.702794Z', 'updated_by': [{'user_id': 10}]}, image_id=111909, user_id=25))

# %%
species_label_by_image_id = {label.image_id: label for label in species_labels}

len(species_label_by_image_id)
# Out:
# 1218

# %%
grouped_species_labels = [[[(group.dive_id, species_label_by_image_id[idx]) for idx in group.image_ids] for group in dive] for dive in dive_image_groups_list]

len(grouped_species_labels), len(grouped_species_labels[0]), len(grouped_species_labels[0][0]), grouped_species_labels[0][1][0:5]
# Out:
# (8,
#  13,
#  65,
#  [(383,
#    SpeciesLabel(id=1205, label_studio_task_id=224649, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194', updated_at=datetime.datetime(2025, 12, 9, 1, 17, 29, 655924, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image='Fish, Other (Identifiable but Nontarget)', fish_measurable_category='yes, center of fish', fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134898, 'result': [{'id': 'XPb8z957rQ', 'type': 'taxonomy', 'value': {'taxonomy': [['Fish', 'Other (Identifiable but Nontarget)']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'ETPOSS0HCV', 'type': 'taxonomy', 'value': {'taxonomy': [['yes, center of fish']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'measurable'}], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 46\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:17:29.655912Z', 'updated_at': '2025-12-09T01:17:29.655924Z', 'draft_created_at': '2025-12-09T01:17:07.094334Z', 'lead_time': 31.836, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224649, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134898', 'annotations_results': '[{id:XPb8z957rQ, type:taxonomy, value:{taxonomy:[[Fish, Other (Identifiable but Nontarget)]]}, origin:manual, to_name:image, from_name:species},{id:ETPOSS0HCV, type:taxonomy, value:{taxonomy:[[yes, center of fish]]}, origin:manual, to_name:image, from_name:measurable}]', 'annotators': [10], 'avg_lead_time': 31.836, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:17:29.655912Z', 'created_at': '2025-12-08T22:46:39.908751Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224649, 'inner_id': 27, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:17:29.807875Z', 'updated_by': [{'user_id': 10}]}, image_id=111935, user_id=25)),
#   (383,
#    SpeciesLabel(id=1205, label_studio_task_id=224649, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194', updated_at=datetime.datetime(2025, 12, 9, 1, 17, 29, 655924, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image='Fish, Other (Identifiable but Nontarget)', fish_measurable_category='yes, center of fish', fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134898, 'result': [{'id': 'XPb8z957rQ', 'type': 'taxonomy', 'value': {'taxonomy': [['Fish', 'Other (Identifiable but Nontarget)']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'ETPOSS0HCV', 'type': 'taxonomy', 'value': {'taxonomy': [['yes, center of fish']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'measurable'}], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 46\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:17:29.655912Z', 'updated_at': '2025-12-09T01:17:29.655924Z', 'draft_created_at': '2025-12-09T01:17:07.094334Z', 'lead_time': 31.836, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224649, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134898', 'annotations_results': '[{id:XPb8z957rQ, type:taxonomy, value:{taxonomy:[[Fish, Other (Identifiable but Nontarget)]]}, origin:manual, to_name:image, from_name:species},{id:ETPOSS0HCV, type:taxonomy, value:{taxonomy:[[yes, center of fish]]}, origin:manual, to_name:image, from_name:measurable}]', 'annotators': [10], 'avg_lead_time': 31.836, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:17:29.655912Z', 'created_at': '2025-12-08T22:46:39.908751Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224649, 'inner_id': 27, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:17:29.807875Z', 'updated_by': [{'user_id': 10}]}, image_id=111935, user_id=25)),
#   (383,
#    SpeciesLabel(id=1205, label_studio_task_id=224649, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194', updated_at=datetime.datetime(2025, 12, 9, 1, 17, 29, 655924, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image='Fish, Other (Identifiable but Nontarget)', fish_measurable_category='yes, center of fish', fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134898, 'result': [{'id': 'XPb8z957rQ', 'type': 'taxonomy', 'value': {'taxonomy': [['Fish', 'Other (Identifiable but Nontarget)']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'ETPOSS0HCV', 'type': 'taxonomy', 'value': {'taxonomy': [['yes, center of fish']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'measurable'}], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 46\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:17:29.655912Z', 'updated_at': '2025-12-09T01:17:29.655924Z', 'draft_created_at': '2025-12-09T01:17:07.094334Z', 'lead_time': 31.836, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224649, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134898', 'annotations_results': '[{id:XPb8z957rQ, type:taxonomy, value:{taxonomy:[[Fish, Other (Identifiable but Nontarget)]]}, origin:manual, to_name:image, from_name:species},{id:ETPOSS0HCV, type:taxonomy, value:{taxonomy:[[yes, center of fish]]}, origin:manual, to_name:image, from_name:measurable}]', 'annotators': [10], 'avg_lead_time': 31.836, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:17:29.655912Z', 'created_at': '2025-12-08T22:46:39.908751Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224649, 'inner_id': 27, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:17:29.807875Z', 'updated_by': [{'user_id': 10}]}, image_id=111935, user_id=25)),
#   (383,
#    SpeciesLabel(id=1205, label_studio_task_id=224649, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194', updated_at=datetime.datetime(2025, 12, 9, 1, 17, 29, 655924, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image='Fish, Other (Identifiable but Nontarget)', fish_measurable_category='yes, center of fish', fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134898, 'result': [{'id': 'XPb8z957rQ', 'type': 'taxonomy', 'value': {'taxonomy': [['Fish', 'Other (Identifiable but Nontarget)']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'ETPOSS0HCV', 'type': 'taxonomy', 'value': {'taxonomy': [['yes, center of fish']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'measurable'}], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 46\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:17:29.655912Z', 'updated_at': '2025-12-09T01:17:29.655924Z', 'draft_created_at': '2025-12-09T01:17:07.094334Z', 'lead_time': 31.836, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224649, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134898', 'annotations_results': '[{id:XPb8z957rQ, type:taxonomy, value:{taxonomy:[[Fish, Other (Identifiable but Nontarget)]]}, origin:manual, to_name:image, from_name:species},{id:ETPOSS0HCV, type:taxonomy, value:{taxonomy:[[yes, center of fish]]}, origin:manual, to_name:image, from_name:measurable}]', 'annotators': [10], 'avg_lead_time': 31.836, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:17:29.655912Z', 'created_at': '2025-12-08T22:46:39.908751Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224649, 'inner_id': 27, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:17:29.807875Z', 'updated_by': [{'user_id': 10}]}, image_id=111935, user_id=25)),
#   (383,
#    SpeciesLabel(id=1205, label_studio_task_id=224649, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194', updated_at=datetime.datetime(2025, 12, 9, 1, 17, 29, 655924, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image='Fish, Other (Identifiable but Nontarget)', fish_measurable_category='yes, center of fish', fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134898, 'result': [{'id': 'XPb8z957rQ', 'type': 'taxonomy', 'value': {'taxonomy': [['Fish', 'Other (Identifiable but Nontarget)']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'ETPOSS0HCV', 'type': 'taxonomy', 'value': {'taxonomy': [['yes, center of fish']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'measurable'}], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 46\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:17:29.655912Z', 'updated_at': '2025-12-09T01:17:29.655924Z', 'draft_created_at': '2025-12-09T01:17:07.094334Z', 'lead_time': 31.836, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224649, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134898', 'annotations_results': '[{id:XPb8z957rQ, type:taxonomy, value:{taxonomy:[[Fish, Other (Identifiable but Nontarget)]]}, origin:manual, to_name:image, from_name:species},{id:ETPOSS0HCV, type:taxonomy, value:{taxonomy:[[yes, center of fish]]}, origin:manual, to_name:image, from_name:measurable}]', 'annotators': [10], 'avg_lead_time': 31.836, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:17:29.655912Z', 'created_at': '2025-12-08T22:46:39.908751Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/b79fed084d5817f81b37aaa4164f1194'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224649, 'inner_id': 27, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:17:29.807875Z', 'updated_by': [{'user_id': 10}]}, image_id=111935, user_id=25))])

# %%
dive_groups = []

current_group = []
for dive_label_group in grouped_species_labels:
    dive = []

    for label_group in dive_label_group:
        for idx, (dive_id, label) in enumerate(label_group):
            if (idx == 0 and label.grouping != "Part of previous group") or label.grouping == "Not part of current group":
                if current_group:
                    dive.append(current_group)
                current_group = []

            current_group.append((dive_id, label))

    if current_group:
        dive.append(current_group)
        current_group = []

    if dive:
        dive_groups.append(dive)
        dive = []

len(dive_groups), len(dive_groups[0]), dive_groups[0]
# Out:
# (8,
#  39,
#  [[(383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1203, label_studio_task_id=224644, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 11, 765996, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134893, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:11.765983Z', 'updated_at': '2025-12-09T01:15:11.765996Z', 'draft_created_at': None, 'lead_time': 26.865, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224644, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134893', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 26.865, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:11.765983Z', 'created_at': '2025-12-08T22:46:39.908605Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c5cef715ad648236aac9c06f762d2ead'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224644, 'inner_id': 22, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:11.917867Z', 'updated_by': [{'user_id': 10}]}, image_id=111930, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
#     SpeciesLabel(id=1200, label_studio_task_id=224645, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7', updated_at=datetime.datetime(2025, 12, 9, 1, 15, 24, 269975, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=None, laser_y=None, laser_label=None, content_of_image=None, fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134894, 'result': [], 'created_username': ' alli@reef.org, 10', 'created_ago': '1\xa0hour, 48\xa0minutes', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:15:24.269963Z', 'updated_at': '2025-12-09T01:15:24.269975Z', 'draft_created_at': None, 'lead_time': 11.356, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224645, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134894', 'annotations_results': '[]', 'annotators': [10], 'avg_lead_time': 11.356, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:15:24.269963Z', 'created_at': '2025-12-08T22:46:39.908635Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/c7e168db6dd10533af694a1a637409b7'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224645, 'inner_id': 23, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:15:24.419179Z', 'updated_by': [{'user_id': 10}]}, image_id=111931, user_id=25)),
#    (383,
# ...
#    (383,
#     SpeciesLabel(id=1185, label_studio_task_id=224625, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501', updated_at=datetime.datetime(2025, 12, 9, 1, 2, 31, 699241, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=2065.2678694696647, laser_y=1415.7349545196723, laser_label='Red Laser', content_of_image='Slate, Laser on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134873, 'result': [{'id': '5UqLThXCyn', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'PC0zwaqQcH', 'type': 'keypointlabels', 'value': {'x': 51.451616080460006, 'y': 46.940814141898954, 'width': 0.2762390456930156, 'keypointlabels': ['Red Laser']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'created_username': ' alli@reef.org, 10', 'created_ago': '2\xa0hours, 1\xa0minute', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:02:31.699228Z', 'updated_at': '2025-12-09T01:02:31.699241Z', 'draft_created_at': '2025-12-09T01:02:24.498449Z', 'lead_time': 18.928, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224625, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134873', 'annotations_results': '[{id:5UqLThXCyn, type:taxonomy, value:{taxonomy:[[Slate, Laser on slate]]}, origin:manual, to_name:image, from_name:species},{id:PC0zwaqQcH, type:keypointlabels, value:{x:51.45, y:46.94, width:0.28, keypointlabels:[Red Laser]}, origin:manual, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'annotators': [10], 'avg_lead_time': 18.928, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:02:31.699228Z', 'created_at': '2025-12-08T22:46:39.907877Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224625, 'inner_id': 3, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:02:31.845609Z', 'updated_by': [{'user_id': 10}]}, image_id=111911, user_id=25)),
#    (383,
#     SpeciesLabel(id=1185, label_studio_task_id=224625, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501', updated_at=datetime.datetime(2025, 12, 9, 1, 2, 31, 699241, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=2065.2678694696647, laser_y=1415.7349545196723, laser_label='Red Laser', content_of_image='Slate, Laser on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134873, 'result': [{'id': '5UqLThXCyn', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'PC0zwaqQcH', 'type': 'keypointlabels', 'value': {'x': 51.451616080460006, 'y': 46.940814141898954, 'width': 0.2762390456930156, 'keypointlabels': ['Red Laser']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'created_username': ' alli@reef.org, 10', 'created_ago': '2\xa0hours, 1\xa0minute', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:02:31.699228Z', 'updated_at': '2025-12-09T01:02:31.699241Z', 'draft_created_at': '2025-12-09T01:02:24.498449Z', 'lead_time': 18.928, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224625, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134873', 'annotations_results': '[{id:5UqLThXCyn, type:taxonomy, value:{taxonomy:[[Slate, Laser on slate]]}, origin:manual, to_name:image, from_name:species},{id:PC0zwaqQcH, type:keypointlabels, value:{x:51.45, y:46.94, width:0.28, keypointlabels:[Red Laser]}, origin:manual, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'annotators': [10], 'avg_lead_time': 18.928, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:02:31.699228Z', 'created_at': '2025-12-08T22:46:39.907877Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224625, 'inner_id': 3, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:02:31.845609Z', 'updated_by': [{'user_id': 10}]}, image_id=111911, user_id=25)),
#    (383,
#     SpeciesLabel(id=1185, label_studio_task_id=224625, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501', updated_at=datetime.datetime(2025, 12, 9, 1, 2, 31, 699241, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=2065.2678694696647, laser_y=1415.7349545196723, laser_label='Red Laser', content_of_image='Slate, Laser on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134873, 'result': [{'id': '5UqLThXCyn', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'PC0zwaqQcH', 'type': 'keypointlabels', 'value': {'x': 51.451616080460006, 'y': 46.940814141898954, 'width': 0.2762390456930156, 'keypointlabels': ['Red Laser']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'created_username': ' alli@reef.org, 10', 'created_ago': '2\xa0hours, 1\xa0minute', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:02:31.699228Z', 'updated_at': '2025-12-09T01:02:31.699241Z', 'draft_created_at': '2025-12-09T01:02:24.498449Z', 'lead_time': 18.928, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224625, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134873', 'annotations_results': '[{id:5UqLThXCyn, type:taxonomy, value:{taxonomy:[[Slate, Laser on slate]]}, origin:manual, to_name:image, from_name:species},{id:PC0zwaqQcH, type:keypointlabels, value:{x:51.45, y:46.94, width:0.28, keypointlabels:[Red Laser]}, origin:manual, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'annotators': [10], 'avg_lead_time': 18.928, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:02:31.699228Z', 'created_at': '2025-12-08T22:46:39.907877Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224625, 'inner_id': 3, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:02:31.845609Z', 'updated_by': [{'user_id': 10}]}, image_id=111911, user_id=25)),
#    (383,
#     SpeciesLabel(id=1185, label_studio_task_id=224625, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501', updated_at=datetime.datetime(2025, 12, 9, 1, 2, 31, 699241, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=2065.2678694696647, laser_y=1415.7349545196723, laser_label='Red Laser', content_of_image='Slate, Laser on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134873, 'result': [{'id': '5UqLThXCyn', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'PC0zwaqQcH', 'type': 'keypointlabels', 'value': {'x': 51.451616080460006, 'y': 46.940814141898954, 'width': 0.2762390456930156, 'keypointlabels': ['Red Laser']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'created_username': ' alli@reef.org, 10', 'created_ago': '2\xa0hours, 1\xa0minute', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:02:31.699228Z', 'updated_at': '2025-12-09T01:02:31.699241Z', 'draft_created_at': '2025-12-09T01:02:24.498449Z', 'lead_time': 18.928, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224625, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134873', 'annotations_results': '[{id:5UqLThXCyn, type:taxonomy, value:{taxonomy:[[Slate, Laser on slate]]}, origin:manual, to_name:image, from_name:species},{id:PC0zwaqQcH, type:keypointlabels, value:{x:51.45, y:46.94, width:0.28, keypointlabels:[Red Laser]}, origin:manual, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'annotators': [10], 'avg_lead_time': 18.928, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:02:31.699228Z', 'created_at': '2025-12-08T22:46:39.907877Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224625, 'inner_id': 3, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:02:31.845609Z', 'updated_by': [{'user_id': 10}]}, image_id=111911, user_id=25)),
#    (383,
#     SpeciesLabel(id=1185, label_studio_task_id=224625, label_studio_project_id=70, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501', updated_at=datetime.datetime(2025, 12, 9, 1, 2, 31, 699241, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=None, laser_x=2065.2678694696647, laser_y=1415.7349545196723, laser_label='Red Laser', content_of_image='Slate, Laser on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 134873, 'result': [{'id': '5UqLThXCyn', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'PC0zwaqQcH', 'type': 'keypointlabels', 'value': {'x': 51.451616080460006, 'y': 46.940814141898954, 'width': 0.2762390456930156, 'keypointlabels': ['Red Laser']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'created_username': ' alli@reef.org, 10', 'created_ago': '2\xa0hours, 1\xa0minute', 'completed_by': 10, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-12-09T01:02:31.699228Z', 'updated_at': '2025-12-09T01:02:31.699241Z', 'draft_created_at': '2025-12-09T01:02:24.498449Z', 'lead_time': 18.928, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 224625, 'project': 70, 'updated_by': 10, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '134873', 'annotations_results': '[{id:5UqLThXCyn, type:taxonomy, value:{taxonomy:[[Slate, Laser on slate]]}, origin:manual, to_name:image, from_name:species},{id:PC0zwaqQcH, type:keypointlabels, value:{x:51.45, y:46.94, width:0.28, keypointlabels:[Red Laser]}, origin:manual, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'annotators': [10], 'avg_lead_time': 18.928, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-12-09T01:02:31.699228Z', 'created_at': '2025-12-08T22:46:39.907877Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/a16c10d11e3ea788f966800c77af1501'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 224625, 'inner_id': 3, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [], 'predictions_model_versions': '', 'predictions_results': '', 'predictions_score': None, 'project': 70, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 0, 'unresolved_comment_count': 0, 'updated_at': '2025-12-09T01:02:31.845609Z', 'updated_by': [{'user_id': 10}]}, image_id=111911, user_id=25))]])

# %%
async with Client(settings.fishsense_api.url, settings.fishsense_api.username, settings.fishsense_api.password) as client:
    for dive in tqdm(dive_groups):
        for grouping in dive:
            dive_id = grouping[0][0]

            cluster = DiveFrameCluster(
                id = None,
                dive_id=dive_id,
                image_ids=[label.image_id for _, label in grouping],
                data_source="LABEL_STUDIO",
                fish_id=None,
                updated_at=datetime.now(timezone.utc)
            )
                
            await client.images.post_cluster(dive_id, cluster)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
