# %%
from fishsense_api_sdk.client import Client
from label_studio_sdk.client import LabelStudio
from pathlib import Path
from typing import List
from fishsense_api_sdk.models.species_label import SpeciesLabel
from tqdm.asyncio import tqdm_asyncio
from tqdm.notebook import tqdm
from fishsense_api_sdk.models.dive_slate_label import DiveSlateLabel

# %%
URL = "http://localhost:8000"
PROJECT_ID = 66

# %%
label_studio_api_key = Path("..") / ".label_studio_api_key"

label_studio_api_key.exists()
# Out:
# True

# %%
ls = LabelStudio(base_url=f"https://labeler.e4e.ucsd.edu", api_key=label_studio_api_key.read_text().strip())

# %%
async with Client(base_url=URL) as fs:
    dives = await fs.dives.get_canonical()
    dives = [dive for dive in dives if dive.priority == "HIGH"]

len(dives), dives[0]
# Out:
# (7,
#  Dive(id=279, name='111323_Alligator DeepEast Drift2_FSL05', path='drive-download-20240307T1050Z/112023_Alligator/111323_Alligator/111323_Alligator_FSL05/111323_Alligator DeepEast Drift2_FSL05', dive_datetime=datetime.datetime(2023, 11, 13, 12, 34, 8, tzinfo=TzInfo(0)), priority=<Priority.HIGH: 'HIGH'>, flip_dive_slate=None, camera_id=5, dive_slate_id=7))

# %%
species_labels: List[SpeciesLabel] = await tqdm_asyncio.gather(*[fs.labels.get_species_labels(dive.id) for dive in dives])
species_labels = [label for sublist in species_labels for label in sublist]

len(species_labels), species_labels[0]
# Out:
# 100%|██████████| 7/7 [00:01<00:00,  4.89it/s]
# (1178,
#  SpeciesLabel(id=1024, label_studio_task_id=222252, label_studio_project_id=57, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/7252dfb0db0b855616e45607f58c1c93', updated_at=datetime.datetime(2025, 10, 20, 20, 42, 14, 832143, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=True, laser_x=1970.0, laser_y=1340.0, laser_label='Red Laser', content_of_image='Slate, Laser not on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 117942, 'result': [{'id': 'result1', 'type': 'keypointlabels', 'value': {'x': 49.08221189998697, 'y': 44.44128413294742, 'width': 0.2, 'keypointlabels': ['Red Laser']}, 'origin': 'prediction-changed', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}, {'id': 'm4K68yydiZ', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser not on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': 'V_e6mRtCE1', 'type': 'choices', 'value': {'choices': ['Slate upside down']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'slate'}], 'created_username': 'Christopher Crutchfield ccrutchf@ucsd.edu, 4', 'created_ago': '1\xa0month', 'completed_by': 4, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-10-15T21:10:56.570698Z', 'updated_at': '2025-10-20T20:42:14.832143Z', 'draft_created_at': '2025-10-15T21:10:51.955430Z', 'lead_time': 218.90899999999996, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 222252, 'project': 57, 'updated_by': 4, 'parent_prediction': 19891, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '117942', 'annotations_results': '[{id:result1, type:keypointlabels, value:{x:49.08, y:44.44, width:0.2, keypointlabels:[Red Laser]}, origin:prediction-changed, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016},{id:m4K68yydiZ, type:taxonomy, value:{taxonomy:[[Slate, Laser not on slate]]}, origin:manual, to_name:image, from_name:species},{id:V_e6mRtCE1, type:choices, value:{choices:[Slate upside down]}, origin:manual, to_nam', 'annotators': [4], 'avg_lead_time': 218.90899999999996, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-10-15T21:10:56.570698Z', 'created_at': '2025-10-15T18:40:24.543620Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/7252dfb0db0b855616e45607f58c1c93'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 222252, 'inner_id': 1, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [{'created_at': '2025-10-15T18:40:24.601785Z', 'model': None, 'model_run': None, 'model_version': 'sql', 'project': 57, 'result': [{'id': 'result1', 'type': 'keypointlabels', 'value': {'x': 49.097406784620766, 'y': 44.431622327916884, 'width': 0.2, 'keypointlabels': ['Red Laser']}, 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'score': None, 'task': 222252, 'updated_at': '2025-10-15T18:40:24.601798Z', 'id': 19891, 'created_ago': '1\xa0month', 'cluster': None, 'neighbors': None, 'mislabeling': 0.0}], 'predictions_model_versions': 'sql', 'predictions_results': '[{id:result1, type:keypointlabels, value:{x:49.1, y:44.43, width:0.2, keypointlabels:[Red Laser]}, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'predictions_score': None, 'project': 57, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 1, 'unresolved_comment_count': 0, 'updated_at': '2025-10-20T20:42:15.009930Z', 'updated_by': [{'user_id': 4}]}, image_id=78666, user_id=114))

# %%
slate_labels = [label for label in species_labels if label.content_of_image == 'Slate, Laser on slate']

len(slate_labels), slate_labels[0]
# Out:
# (95,
#  SpeciesLabel(id=1044, label_studio_task_id=222272, label_studio_project_id=57, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/2863b55ffedf2bbb1e94f8042fd8ad60', updated_at=datetime.datetime(2025, 10, 21, 1, 8, 15, 395055, tzinfo=TzInfo(0)), completed=True, grouping=None, top_three_photos_of_group=None, slate_upside_down=True, laser_x=1851.0, laser_y=902.0, laser_label='Red Laser', content_of_image='Slate, Laser on slate', fish_measurable_category=None, fish_angle_category=None, fish_curved_category=None, label_studio_json={'annotations': [{'id': 117986, 'result': [{'id': 'result1', 'type': 'keypointlabels', 'value': {'x': 46.10335466840985, 'y': 29.916128498866595, 'width': 0.2, 'keypointlabels': ['Red Laser']}, 'origin': 'prediction', 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}, {'id': 'xON5aKx1k3', 'type': 'taxonomy', 'value': {'taxonomy': [['Slate', 'Laser on slate']]}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'species'}, {'id': '4jOvs8zB2L', 'type': 'choices', 'value': {'choices': ['Slate upside down']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'slate'}], 'created_username': ' jen.loch@reef.org, 26', 'created_ago': '1\xa0month', 'completed_by': 26, 'was_cancelled': False, 'ground_truth': False, 'created_at': '2025-10-16T16:28:17.442202Z', 'updated_at': '2025-10-21T01:08:15.395055Z', 'draft_created_at': '2025-10-16T16:28:17.140265Z', 'lead_time': 35.83, 'import_id': None, 'last_action': None, 'bulk_created': False, 'task': 222272, 'project': 57, 'updated_by': 10, 'parent_prediction': 19905, 'parent_annotation': None, 'last_created_by': None}], 'annotations_ids': '117986', 'annotations_results': '[{id:result1, type:keypointlabels, value:{x:46.1, y:29.92, width:0.2, keypointlabels:[Red Laser]}, origin:prediction, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016},{id:xON5aKx1k3, type:taxonomy, value:{taxonomy:[[Slate, Laser on slate]]}, origin:manual, to_name:image, from_name:species},{id:4jOvs8zB2L, type:choices, value:{choices:[Slate upside down]}, origin:manual, to_name:image, f', 'annotators': [26], 'avg_lead_time': 35.83, 'cancelled_annotations': 0, 'comment_authors': [], 'comment_count': 0, 'completed_at': '2025-10-16T16:28:17.442202Z', 'created_at': '2025-10-15T18:40:24.544369Z', 'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/groups_jpeg/2863b55ffedf2bbb1e94f8042fd8ad60'}, 'draft_exists': False, 'drafts': [], 'file_upload': None, 'id': 222272, 'inner_id': 21, 'is_labeled': True, 'last_comment_updated_at': None, 'meta': {}, 'overlap': 1, 'predictions': [{'created_at': '2025-10-15T18:40:24.602141Z', 'model': None, 'model_run': None, 'model_version': 'sql', 'project': 57, 'result': [{'id': 'result1', 'type': 'keypointlabels', 'value': {'x': 46.10335466840985, 'y': 29.916128498866595, 'width': 0.2, 'keypointlabels': ['Red Laser']}, 'to_name': 'image', 'from_name': 'laser', 'image_rotation': 0, 'original_width': 4014, 'original_height': 3016}], 'score': None, 'task': 222272, 'updated_at': '2025-10-15T18:40:24.602144Z', 'id': 19905, 'created_ago': '1\xa0month', 'cluster': None, 'neighbors': None, 'mislabeling': 0.0}], 'predictions_model_versions': 'sql', 'predictions_results': '[{id:result1, type:keypointlabels, value:{x:46.1, y:29.92, width:0.2, keypointlabels:[Red Laser]}, to_name:image, from_name:laser, image_rotation:0, original_width:4014, original_height:3016}]', 'predictions_score': None, 'project': 57, 'storage_filename': None, 'total_annotations': 1, 'total_predictions': 1, 'unresolved_comment_count': 0, 'updated_at': '2025-10-21T01:08:15.593385Z', 'updated_by': [{'user_id': 10}]}, image_id=78686, user_id=19))

# %%
async with Client(URL) as fs:
    slate_images = await tqdm_asyncio.gather(*[fs.images.get(image_id=label.image_id) for label in slate_labels])

len(slate_images), slate_images[0]
# Out:
# 100%|██████████| 95/95 [00:02<00:00, 35.45it/s]
# (95,
#  Image(id=78686, path='drive-download-20240307T1050Z/112023_Alligator/111323_Alligator/111323_Alligator_FSL05/111323_Alligator DeepEast Drift2_FSL05/PB130190.ORF', taken_datetime=datetime.datetime(2023, 11, 13, 12, 3, 52, tzinfo=TzInfo(0)), checksum='2863b55ffedf2bbb1e94f8042fd8ad60', is_canonical=True, dive_id=279, camera_id=5))

# %%
tasks = []

for image in tqdm(slate_images):
    tasks.append({
        "data": {
            "image": f"https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/{image.checksum}"
        },
        "predictions": [],
        "annotations": []
    })

tasks
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]
# [{'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/2863b55ffedf2bbb1e94f8042fd8ad60'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/ae65a40aae9d2a8af6cc440775b5f64a'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/a97161b74530f64d7b364108ea098d20'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/ff7e76aff9bdd3147a3ffd1942df9f27'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/9008aea58024e6d14d7e6516b7897e5e'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/917db3f3dcf07f1812dfb0b60c8c66e5'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/8bf6e282e94e008222c9eeff35cd07b2'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/850b37639354dfadce88d6bb5dafb245'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/3022f12084d0026ff3080f936a44fa74'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/04969f572c38c5ab75ab7ab9b924a9f9'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/f577cae544a4a9a6c135698a7b111b09'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/82db7943d88f79152816c7139538f03a'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/e7ddc5c76c8df964b8372dcc003ca0f8'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/a590ccba0c2c366449413eccc05b8ee4'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/3a61b99128a8af2111570bdce2cb627f'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/830dffa9f0b9017901534569144ea8a5'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/9127bb0981f0c993e11275d1bd3806b7'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/a2d181913bf6cc69b06ecf6b71a71b63'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/d9aed1784aff5c7d46cd88d48146864d'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/dd72b66b4c0fbfe26fb75b1edbfb946b'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/b4f777c61e6abeb7903adebebf4da534'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/510cdb8f4535daff25f041981a323ef4'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/7379b882b5d532cc2a3eecee00844e63'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/44ef953f4c6864c823f615aa0deba95d'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/8dc016f5163256bdbf1b83e8bb910236'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/15fafe146841cfdc5bafbb64f0a98096'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/177067216f3ea7f7bd3c35b3095a6db7'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/30bfffadd054af16ddf4c44f12235ec0'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/cf6f08da11d0480c1b51617bdf9cbfb5'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/14bac2a7d3c0fe8b6f27182460cc614e'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/be6c19ac7e1b58dc5d1eb1701302a417'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/f4a19978d5c8b0d99f34daf1325e8fd4'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/e89f1a41c0723435522c491cef558316'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/80c0081f8558ca40aedd7950919952e6'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/a6d7d7f78241b5d6416a9f6da7206d86'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/eba0ecaf645a072d457577a847a6bf72'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/5cc95f2949744cdfbfce2feda027cdb8'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/03267263bb8edd4bfdba55c4dd98df2c'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/27a7aecf1a342f11ce4eb00367dc25b3'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/56975f26d2e2c1281fda306fa95e7baf'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/39d87ebf5c0ff5421c17fa9e2f39a2b9'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/55da02760e71582bfd79a7c99558bc38'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/d2a79aa875f845e16647a54e890f8b09'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/67923221fdfd788bb8f8ed30913588b1'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/faa2d9976fc27f45dff7b66ff96e7531'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/534feb735eaa798cabc65cb4e85a46b9'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/bdc55cd03def27551520e9bc5921eaf0'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/638cbc61c47e66e8d461e76438311d35'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/85448e62d5381f655385ad907c1130e1'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/74d38820fde898cdef0c2664c071c758'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/7e4a4163c09a88c9743e02aa04385640'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/ea18de2b707e05e113d2def1975b2483'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/ad5f5a77aafe79dc99f98805855e44a2'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/92bbabe851f5ac7961b015100987b9fa'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/cff6b7a71f1520721e04b038d974beb5'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/3933a9b1403832b15884b279f0dc4c1e'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/a6b00cbf7aab40665cf5336171b02070'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/6e07c6e2d810e825cb3f398a73a9e9a4'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/05b077e787e476db878eed74bfdf3d6d'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/4c64366a306fca246fc84a7ce7d44973'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/c1d43e383a745194696c35e3bcf81802'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/289039b2aae90a72bf14d990bc0c361d'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/45da39c0de08e6bb8399f1fb9e1b4aee'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/934466836eb60f039192e338b194a1fd'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/80c9d093f91365b26b9c5072cb52947f'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/4b62f884d5b99a712798f4d301a13c2d'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/97eed830f2c34764ca0cb71fdf873939'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/9d7cbc7dd389eb16dbd2c64578f968eb'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/cdabe22284b314ce4a0227c4f88cf032'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/52a7292d2a8b9f9a77fc4ce7a0405db4'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/7852dc286b8018854c3da2142145e483'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/1135734ae6868367ae9d0abbc55ce626'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/c2c80d748234a1d043724663d90466ee'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/b373c90b43bb88207e456f6f7695fc08'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/0ae552fe28e43f967db21d0005833808'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/ca5d6ca482989b22098afeabc7272f07'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/4100468d4a1a7e7de3e8c07d40261648'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/996860b1e1758066a8a89e8b4203c8dd'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/39b7895aabb2f13e20f1042121b54615'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/09618499a395f194fa54364ed449641b'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/3332328a49753c1ab43fcca37e4f67b9'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/5296fa34e22db0badaeef1b5f4da727c'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/fa9f95df23e598e5163ee3185edf342a'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/47b009de2b0387b14b4ed9bcd0606809'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/6214196c336218bf2c9b5af89512b92d'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/2c9ca3a97ab565bfdadb4a492dc5aa7b'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/a2641f9a541065200e6419006944d2fe'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/d861c354ad74438cdeb1db3f4a98e54e'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/e5f5aa01688fef8b14e3e392438aa210'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/36ab56c831ace59c9024de4842b6f7e4'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/8bda788a0b6471980ff21eb345efcddf'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/dc1f5f91e97a3acc0345ad892d44cafa'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/81668de01bf0af448d627366b93e6836'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/c4a38fa75b6ff9150825bca1f119b5b4'},
#   'predictions': [],
#   'annotations': []},
#  {'data': {'image': 'https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/c3caa87e745aa772a34bae00e65d19b3'},
#   'predictions': [],
#   'annotations': []}]

# %%
imported_tasks = ls.projects.import_tasks(PROJECT_ID, request=tasks, return_task_ids=True)

imported_tasks
# Out:
# ProjectsImportTasksResponse(annotation_count=0, could_be_tasks_list=False, data_columns=[], duration=0.16456055641174316, file_upload_ids=[], found_formats=[], predictions_count=None, task_count=95, prediction_count=0, task_ids=[223832, 223833, 223834, 223835, 223836, 223837, 223838, 223839, 223840, 223841, 223842, 223843, 223844, 223845, 223846, 223847, 223848, 223849, 223850, 223851, 223852, 223853, 223854, 223855, 223856, 223857, 223858, 223859, 223860, 223861, 223862, 223863, 223864, 223865, 223866, 223867, 223868, 223869, 223870, 223871, 223872, 223873, 223874, 223875, 223876, 223877, 223878, 223879, 223880, 223881, 223882, 223883, 223884, 223885, 223886, 223887, 223888, 223889, 223890, 223891, 223892, 223893, 223894, 223895, 223896, 223897, 223898, 223899, 223900, 223901, 223902, 223903, 223904, 223905, 223906, 223907, 223908, 223909, 223910, 223911, 223912, 223913, 223914, 223915, 223916, 223917, 223918, 223919, 223920, 223921, 223922, 223923, 223924, 223925, 223926])

# %%
dive_slate_labels = [DiveSlateLabel(id=None, image_id=image.id, label_studio_task_id=task_id, label_studio_project_id=PROJECT_ID, image_url=f"https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/{image.checksum}", updated_at=None, completed=False, label_studio_json={}, user_id=None) for task_id, image in zip(imported_tasks.task_ids, slate_images)]

len(dive_slate_labels), dive_slate_labels[0]
# Out:
# (95,
#  DiveSlateLabel(id=None, label_studio_task_id=223832, label_studio_project_id=66, image_url='https://orchestrator.fishsense.e4e.ucsd.edu/api/v1/data/dive_slate_jpgs/2863b55ffedf2bbb1e94f8042fd8ad60', updated_at=None, completed=False, label_studio_json={}, image_id=78686, user_id=None))

# %%
async with Client(base_url=URL) as fs:
    for dive_slate_label in tqdm(dive_slate_labels):
        await fs.labels.put_dive_slate_label(dive_slate_label.image_id, dive_slate_label)
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]
